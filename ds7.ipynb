# %% [markdown]
# **Discriptive Statistics**

# %%
import pandas as pd
df=pd.read_csv('stats.csv')
df
# Out:
#    Salary    Country
# 0  150000      India
# 1   50000   Pakistan
# 2  100000  Australia
# 3   80000     Africa
# 4  125000        USA

# %% [markdown]
# Measure of Central Tendancy

# %%
# Mean Salary
mean1=df['Salary'].mean()
mean1
# Out:
# 101000.0

# %%
#Sum of Salaries
sum1=df['Salary'].sum()
sum1
# Out:
# 505000

# %%
#Maximum Salary
max1=df['Salary'].max()
max1
# Out:
# 150000

# %%
#Minimum Salary
min1=df['Salary'].min()
min1
# Out:
# 50000

# %%
#Total count

count1=df['Salary'].count()
count1
# Out:
# 5

# %%
#Median
median=df['Salary'].median()
median
# Out:
# 100000.0

# %%
#Mode
mode1=df['Salary'].mode()
mode1
# Out:
# 0     50000
# 1     80000
# 2    100000
# 3    125000
# 4    150000
# Name: Salary, dtype: int64

# %%
countrywise_sum=df.groupby(['Country'])['Salary'].sum()
countrywise_sum
# Out:
# Country
# Africa        80000
# Australia    100000
# India        150000
# Pakistan      50000
# USA          125000
# Name: Salary, dtype: int64

# %%
countrywise_count=df.groupby(['Country']).count()
countrywise_count
# Out:
#            Salary
# Country
# Africa          1
# Australia       1
# India           1
# Pakistan        1
# USA             1

# %% [markdown]
# Measure of variability

# %%
#variance of salaries
var1=df['Salary'].var()
var1
# Out:
# 1505000000.0

# %%
#standard deviation
std1=df['Salary'].std()
std1
# Out:
# 38794.329482541645

# %% [markdown]
# Measure of Symmetry

# %%
skew1=df.skew(axis=0, skipna=True)
skew1
# Out:
# <ipython-input-13-0d1928590414>:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   skew1=df.skew(axis=0, skipna=True)
# Salary   -0.074505
# dtype: float64

# %%
#The skewness is positive so x will have right side tail.
df.describe()
# Out:
#               Salary
# count       5.000000
# mean   101000.000000
# std     38794.329483
# min     50000.000000
# 25%     80000.000000
# 50%    100000.000000
# 75%    125000.000000
# max    150000.000000
